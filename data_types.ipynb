# %%
# datatypes

# %% [raw]
# Data types define the type of value a variable can store. Python automatically assigns data types based on the value.

# %% [markdown]
# # 1)numeric datatype

# %% [raw]
# Types:
# 	•	int → whole numbers
# 	•	float → decimal numbers
# 	•	complex → numbers with real + imaginary part

# %%
a = 1   # int
b =2.5  # float
c = 1 +2j #complex

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2.5

# %%
c
# Out:
# (1+2j)

# %%
print(a,b,c)
# Out:
# 1 2.5 (1+2j)

# %%
print(a,b)
# Out:
# 1 2.5

# %% [markdown]
# # 2)string

# %% [raw]
# A sequence of characters enclosed in quotes.

# %%
print ('ajit is good boy , he likes to code')
# Out:
# ajit is good boy , he likes to code

# %%
print("""ajit is good boy,
he likes to code""")
# Out:
# ajit is good boy,
# he likes to code

# %% [markdown]
# # 3)boolean

# %% [raw]
# true false

# %%
5<4
# Out:
# False

# %% [markdown]
# # 3) variable

# %%
a = 1
b = 2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
a_1 = 2

# %%
a_1
# Out:
# 2

# %% [raw]
# // cann not be numberic value

# %% [markdown]
# # operation in python

# %%
a = 1

# %%
type (a)
# Out:
# int

# %%
b = 1.233

# %%
type(b)
# Out:
# float

# %%
b = 2

# %%
c = a + b

# %%
c
# Out:
# 3

# %%
d = "tejas"

# %%
d + c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 d + c
#
# TypeError: can only concatenate str (not "int") to str

# %%
e=2.2

# %%
a+e
# Out:
# 3.2

# %%
"hello"+ "hello"
# Out:
# 'hellohello'

# %% [markdown]
# # f formating

# %%
age = 40
print ('age is',age)
# Out:
# age is 40

# %%
print (f'age is {age}')
# Out:
# age is 40

# %%
name = input("enter your name")
age = input("enter your age")
print("your name", name
# Out:
# enter your name trjas
# enter your age 12
# your name trjas

# %%
name = input("enter your name")
age = input("enter your age")
print(f"your name {name} and age is {age}")
# Out:
# enter your name tejas
# enter your age 12
# your name tejas and age is 12
